# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
file = "raw_data/2019-Housing-Inventory-Count-Raw-File.xlsx"

# %%
# Read our Data file with the pandas library
readFile = pd.read_excel(file)
readFile
# Out:
#         Row # CocState                                 CoC  Coc\ID  HudNum  \
# 0      385019       OH  Akron, Barberton/Summit County CoC    1350  OH-506
# 1      385020       OH  Akron, Barberton/Summit County CoC    1350  OH-506
# 2      385027       OH  Akron, Barberton/Summit County CoC    1350  OH-506
# 3      352502       AL        Alabama Balance of State CoC    1380  AL-507
# 4      352468       AL        Alabama Balance of State CoC    1380  AL-507
# ...       ...      ...                                 ...     ...     ...
# 25137  355712       WY               Wyoming Statewide CoC    1269  WY-500
# 25138  355735       WY               Wyoming Statewide CoC    1269  WY-500
# 25139  355706       WY               Wyoming Statewide CoC    1269  WY-500
# 25140  368781       WY               Wyoming Statewide CoC    1269  WY-500
# 25141  355707       WY               Wyoming Statewide CoC    1269  WY-500
#
# ...

# %%
#Print all column names
for column in readFile.columns:
    print(column)
# Out:
# Row #
# CocState
# CoC
# Coc\ID
# HudNum
# Status
# year
# Organization ID
# Organization Name
# HMIS Org ID
# Project ID
# Project Name
# HMIS Project ID
# HIC Date
# Project Type
# Bed Type
# Geo Code
# Inventory Type
# beginsOperationsWithinYear
# Target Population
# Mc Kinney-Vento
# mcKinneyVentoEsg
# mcKinneyVentoEsgEs
# mcKinneyVentoEsgRrh
# mcKinneyVentoCoc
# mcKinneyVentoCocSh
# mcKinneyVentoCocTh
# mcKinneyVentoCocPsh
# mcKinneyVentoCocRrh
# mcKinneyVentoCocSro
# mcKinneyVentoSpC
# mcKinneyVentoS8
# mcKinneyVentoShp
# federalFunding
# federalFundingVash
# federalFundingSsvf
# federalFundingGpd
# federalFundingGpdBh
# federalFundingGpdLd
# federalFundingGpdHh
# federalFundingGpdCt
# federalFundingGpdSith
# federalFundingGpdTp
# federalFundingHchv
# federalFundingHchvCrs
# federalFundingHchvSh
# federalFundingCwt
# federalFundingBcp
# federalFundingTlp
# federalFundingMgh
# federalFundingRhyDp
# federalFundingHopwa
# federalFundingHopwaHmv
# federalFundingHopwaPh
# ...
